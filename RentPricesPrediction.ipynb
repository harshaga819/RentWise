# %% [markdown]
# #  Jaipur Rent Prices Prediction

# %% [markdown]
# ##  Problem Statement
#
# > In urban areas, rapidly changing housing markets make it difficult for tenants and property owners to estimate fair rental prices. This project aims to build a machine learning model that accurately predicts rental prices based on property features such as location, area, number of BHKs, and furnishing status.
# >
# > The goal is to assist both renters and landlords in making data-driven decisions, improving the transparency and efficiency of rental negotiations.

# %% [markdown]
# ## Real-World Use Case
#
# > **Rental Market Platforms (e.gs, MagicBricks):** Predictive models can help suggest reasonable price ranges for new listings.
# > **Tenants:** Ensure they are not overpaying based on similar listings in the market.
# > **Landlords/Property Managers:** Set competitive rental prices to attract tenants faster.
# > **Real Estate Analysts:** Analyze trends and forecast rental price behavior over time.

# %% [markdown]
# ## Table of Contents
#
# 1. Data Collection
# 2. Data Preprocessing
# 3. Exploratory Data Analysis (EDA)
# 4. Pre-modeling Data Preparation
# 5. Data Splitting
# 6. Model Building & Evaluation
# 7. Conclusion & Insights

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## 1. Data Collection
# > In this step we will import the data from the excel file which we have generated by **web scraping** the MagicBricks.com website

# %%
df=pd.read_excel('jaipur_rent.xlsx')

# %%
df.head()
# Out:
#       Rent BHK      Furnishing  Tenant Preferred Carpet Area  \
# 0  ₹26,000   2       Furnished  Bachelors/Family   1230 sqft
# 1  ₹20,000   2     Unfurnished  Bachelors/Family   1100 sqft
# 2   ₹7,000   1  Semi-Furnished  Bachelors/Family    800 sqft
# 3  ₹12,000   2  Semi-Furnished  Bachelors/Family   1310 sqft
# 4  ₹32,000   2       Furnished  Bachelors/Family   1458 sqft
#
#                       Location  Floor
# 0             Jagatpura Jaipur    3.0
# 1            Mansarovar Jaipur    3.0
# 2          Manglam City Jaipur    NaN
# 3  Vatika Infotech City Jaipur   12.0
# 4             Jagatpura Jaipur    2.0

# %% [markdown]
# #

# %% [markdown]
# ## 2. Data Preprocessing
# > In this phase, we clean and standardize the data to ensure quality and consistency.
# >
# > Tasks include handling missing values, correcting data types, removing duplicates, and ensuring uniform formatting.
# >
# > Clean data is crucial for reliable analytics and modeling.

# %% [markdown]
# #####

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rent              1500 non-null   object
#  1   BHK               1456 non-null   object
#  2   Furnishing        1457 non-null   object
#  3   Tenant Preferred  1500 non-null   object
#  4   Carpet Area       1464 non-null   object
#  5   Location          1500 non-null   object
#  6   Floor             1220 non-null   float64
# dtypes: float64(1), object(6)
# memory usage: 82.2+ KB

# %% [markdown]
# ####

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# Rent                 0.000000
# BHK                  2.933333
# Furnishing           2.866667
# Tenant Preferred     0.000000
# Carpet Area          2.400000
# Location             0.000000
# Floor               18.666667
# dtype: float64

# %% [markdown]
# #####

# %% [markdown]
# #### Correcting data types

# %% [markdown]
# ##### Removing rows whose rent is not given

# %%
df= df[df['Rent'] != 'Call for Price']

# %% [markdown]
# ##### Removing ₹ from rent column

# %%
df["Rent"] = df["Rent"].str.replace("₹", "").str.replace(",", "").str.strip()

# %% [markdown]
# ##### Replacing lac by number

# %%
df["Rent"] = df["Rent"].str.replace(" Lac", "*100000", regex=False)

# %%
df["Rent"] = df["Rent"].map(eval).astype("float")

# %% [markdown]
# ##### Removing '>' and converting it into float

# %%
df['BHK']= df['BHK'].str.replace(">","").astype(float)

# %% [markdown]
# ##### Removing all non-numeric and converting all of them into sqft & converting it into float

# %%
df['Carpet Area']= df['Carpet Area'].str.replace("sqft"," ").str.strip().astype(str)

# %%
df['Carpet Area']= df['Carpet Area'].str.replace("sqm","*10.76").str.strip().astype(str)

# %%
df['Carpet Area']= df['Carpet Area'].str.replace("sqyrd","*9").str.strip().astype(str)

# %%
df['Carpet Area']= df['Carpet Area'].str.replace("nan",'np.nan').str.strip()

# %%
df["Carpet Area"] = df["Carpet Area"].map(eval).astype("float")

# %% [markdown]
# ##### Improve Location column

# %%
df['Location']= df['Location'].str.replace("Jaipur","")
df['Location']= df['Location'].str.replace("in","")
df['Location']= df['Location'].apply(lambda x: x.strip())
df['Location']= df['Location'].map(str.upper)

# %% [markdown]
# ####

# %% [markdown]
# ##### Filling the missing values
# ###### filling the numeric value by median and object type values by mode

# %%
for col in df.columns:
    if df[col].dtype == "object":
        df[col].fillna(df[col].mode()[0], inplace=True)  # Fill with most frequent value
    else:
        df[col].fillna(df[col].median(), inplace=True)     # Fill with mean for numeric

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# Rent                0.0
# BHK                 0.0
# Furnishing          0.0
# Tenant Preferred    0.0
# Carpet Area         0.0
# Location            0.0
# Floor               0.0
# dtype: float64

# %% [markdown]
# ####

# %% [markdown]
# ##### Removing Duplicates

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# #

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)

# %%
df.describe()
# Out:
#                 Rent          BHK   Carpet Area        Floor
# count    1430.000000  1430.000000   1430.000000  1430.000000
# mean    29101.997203     2.404895   1406.983189     3.361538
# std     29029.192581     0.984330    936.520134     2.796590
# min      4500.000000     1.000000     25.000000    -1.000000
# 25%     15000.000000     2.000000    904.000000     1.000000
# 50%     22000.000000     2.000000   1300.000000     3.000000
# 75%     35000.000000     3.000000   1700.000000     4.000000
# max    480000.000000    10.000000  20000.000000    19.000000

# %% [markdown]
# #### Visualization

# %%
plt.figure(figsize=(12,7))
sns.pairplot(df)
plt.show()

# %% [markdown]
# ######

# %%
plt.figure(figsize=(11,3))
sns.boxplot(x=df['Rent'])
plt.show()

# %% [markdown]
# ###### from the above boxplot we can see that there are many outliers present inside the data

# %% [markdown]
# ##### Removing Outliers

# %%
q1= df['Rent'].quantile(0.25)
q3= df['Rent'].quantile(0.75)

iqr= q3 - q1

minrange= q1 - (1.5*iqr)
maxrange= q3 + (1.5*iqr)

df= df[df['Rent']<= maxrange]

# %% [markdown]
# #

# %% [markdown]
# ## 4. Pre-modeling Data Preparation

# %% [markdown]
# #### Feature Engineering
# > Adding a new feature **Price_per_sqft** which is made by dividing Rent by Carpet Area.
# >
# > This gives us rent per sqft of the house.
# >
# > This is a important feature because by this we can estimate the cost better.

# %%
df['Price_per_sqft'] = df['Rent'] / df['Carpet Area']

# %% [markdown]
# ####

# %% [markdown]
# #### Feature Scaling by MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
ms= MinMaxScaler()

# %%
ms.fit(df[['Carpet Area']])
# Out:
# MinMaxScaler()

# %%
df['Carpet Area']= ms.transform(df[['Carpet Area']])

# %% [markdown]
# ####

# %% [markdown]
# #### One Hot Encoding

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
cat_cols = df.select_dtypes(include=["object"]).columns

df = pd.get_dummies(df, columns=cat_cols, drop_first=True)

# %% [markdown]
# ####

# %% [markdown]
# #### Correlation-based feature elimination

# %%
df.corr()
# Out:
#                                         Rent       BHK  Carpet Area     Floor  \
# Rent                                1.000000  0.633402     0.461539  0.283753
# BHK                                 0.633402  1.000000     0.652901  0.198006
# Carpet Area                         0.461539  0.652901     1.000000  0.090450
# Floor                               0.283753  0.198006     0.090450  1.000000
# Price_per_sqft                      0.163204 -0.082495    -0.295137  0.055093
# ...                                      ...       ...          ...       ...
# Location_VIKAS NAGAR               -0.018874 -0.040595    -0.010455 -0.002582
# Location_VISHAL NAGAR NIRMAN NAGAR -0.014523  0.021649     0.006558 -0.002582
# Location_VIT CAMPUS                -0.007997 -0.009473     0.009110 -0.002582
# Location_VIVEK VIHAR METRO STATION -0.003646 -0.009473     0.009960 -0.002582
# Location_VRDAWAN DHAM              -0.025400 -0.040595    -0.003650 -0.002582
#
#                                     Price_per_sqft  Furnishing_Semi-Furnished  \
# Rent                                      0.163204                  -0.139245
# BHK                                      -0.082495                   0.031651
# Carpet Area                              -0.295137                   0.033039
# Floor                                     0.055093                  -0.018207
# Price_per_sqft                            1.000000                  -0.117056
# ...                                            ...                        ...
# Location_VIKAS NAGAR                     -0.010412                   0.032611
# Location_VISHAL NAGAR NIRMAN NAGAR       -0.016874                  -0.022782
# Location_VIT CAMPUS                      -0.014468                  -0.022782
# Location_VIVEK VIHAR METRO STATION       -0.012615                  -0.022782
# Location_VRDAWAN DHAM                    -0.019223                   0.032611
#
#                                     Furnishing_Unfurnished  \
# Rent                                             -0.122705
# BHK                                              -0.051653
# Carpet Area                                      -0.053546
# Floor                                            -0.067417
# Price_per_sqft                                   -0.033854
# ...                                                    ...
# Location_VIKAS NAGAR                             -0.012724
# Location_VISHAL NAGAR NIRMAN NAGAR                0.058391
# Location_VIT CAMPUS                               0.058391
# Location_VIVEK VIHAR METRO STATION                0.058391
# Location_VRDAWAN DHAM                            -0.012724
#
#                                     Tenant Preferred_Bachelors/Family  \
# Rent                                                        -0.235037
# BHK                                                         -0.164012
# Carpet Area                                                 -0.111463
# Floor                                                       -0.124175
# Price_per_sqft                                               0.002414
# ...                                                               ...
# Location_VIKAS NAGAR                                        -0.027892
# Location_VISHAL NAGAR NIRMAN NAGAR                           0.026637
# Location_VIT CAMPUS                                         -0.027892
# Location_VIVEK VIHAR METRO STATION                           0.026637
# Location_VRDAWAN DHAM                                       -0.027892
#
#                                     Tenant Preferred_Family  Location_1RK  \
# Rent                                               0.131255     -0.033014
# BHK                                                0.105024     -0.040595
# Carpet Area                                        0.053976     -0.037676
# Floor                                              0.051883     -0.002582
# Price_per_sqft                                    -0.007120      0.038050
# ...                                                     ...           ...
# Location_VIKAS NAGAR                              -0.009246     -0.000743
# Location_VISHAL NAGAR NIRMAN NAGAR                -0.009246     -0.000743
# Location_VIT CAMPUS                               -0.009246     -0.000743
# Location_VIVEK VIHAR METRO STATION                -0.009246     -0.000743
# Location_VRDAWAN DHAM                             -0.009246     -0.000743
#
#                                     ...  Location_VED VILLA COLONY  \
# Rent                                ...                  -0.022137
# BHK                                 ...                  -0.040595
# Carpet Area                         ...                  -0.027434
# Floor                               ...                  -0.022982
# Price_per_sqft                      ...                   0.010640
# ...                                 ...                        ...
# Location_VIKAS NAGAR                ...                  -0.000743
# Location_VISHAL NAGAR NIRMAN NAGAR  ...                  -0.000743
# Location_VIT CAMPUS                 ...                  -0.000743
# Location_VIVEK VIHAR METRO STATION  ...                  -0.000743
# Location_VRDAWAN DHAM               ...                  -0.000743
#
#                                     Location_VIDHADHAR NAGAR  \
# Rent                                                0.079018
# BHK                                                 0.115015
# Carpet Area                                         0.057597
# Floor                                              -0.002582
# Price_per_sqft                                     -0.001601
# ...                                                      ...
# Location_VIKAS NAGAR                               -0.000743
# Location_VISHAL NAGAR NIRMAN NAGAR                 -0.000743
# Location_VIT CAMPUS                                -0.000743
# Location_VIVEK VIHAR METRO STATION                 -0.000743
# Location_VRDAWAN DHAM                              -0.000743
#
#                                     Location_VIDHYADHAR NAGAR  \
# Rent                                                -0.044983
# BHK                                                 -0.048705
# Carpet Area                                         -0.023849
# Floor                                               -0.027196
# Price_per_sqft                                      -0.009607
# ...                                                       ...
# Location_VIKAS NAGAR                                -0.001823
# Location_VISHAL NAGAR NIRMAN NAGAR                  -0.001823
# Location_VIT CAMPUS                                 -0.001823
# Location_VIVEK VIHAR METRO STATION                  -0.001823
# Location_VRDAWAN DHAM                               -0.001823
#
#                                     Location_VIDYADHAR NAGAR  \
# Rent                                                0.007944
# BHK                                                 0.027768
# Carpet Area                                         0.036311
# Floor                                              -0.005170
# Price_per_sqft                                     -0.025091
# ...                                                      ...
# Location_VIKAS NAGAR                               -0.001488
# Location_VISHAL NAGAR NIRMAN NAGAR                 -0.001488
# Location_VIT CAMPUS                                -0.001488
# Location_VIVEK VIHAR METRO STATION                 -0.001488
# Location_VRDAWAN DHAM                              -0.001488
#
#                                     Location_VIDYUT NAGAR  \
# Rent                                            -0.012348
# BHK                                             -0.009473
# Carpet Area                                      0.003155
# Floor                                           -0.022982
# Price_per_sqft                                  -0.014188
# ...                                                   ...
# Location_VIKAS NAGAR                            -0.000743
# Location_VISHAL NAGAR NIRMAN NAGAR              -0.000743
# Location_VIT CAMPUS                             -0.000743
# Location_VIVEK VIHAR METRO STATION              -0.000743
# Location_VRDAWAN DHAM                           -0.000743
#
#                                     Location_VIKAS NAGAR  \
# Rent                                           -0.018874
# BHK                                            -0.040595
# Carpet Area                                    -0.010455
# Floor                                          -0.002582
# Price_per_sqft                                 -0.010412
# ...                                                  ...
# Location_VIKAS NAGAR                            1.000000
# Location_VISHAL NAGAR NIRMAN NAGAR             -0.000743
# Location_VIT CAMPUS                            -0.000743
# Location_VIVEK VIHAR METRO STATION             -0.000743
# Location_VRDAWAN DHAM                          -0.000743
#
#                                     Location_VISHAL NAGAR NIRMAN NAGAR  \
# Rent                                                         -0.014523
# BHK                                                           0.021649
# Carpet Area                                                   0.006558
# Floor                                                        -0.002582
# Price_per_sqft                                               -0.016874
# ...                                                                ...
# Location_VIKAS NAGAR                                         -0.000743
# Location_VISHAL NAGAR NIRMAN NAGAR                            1.000000
# Location_VIT CAMPUS                                          -0.000743
# Location_VIVEK VIHAR METRO STATION                           -0.000743
# Location_VRDAWAN DHAM                                        -0.000743
#
#                                     Location_VIT CAMPUS  \
# Rent                                          -0.007997
# BHK                                           -0.009473
# Carpet Area                                    0.009110
# Floor                                         -0.002582
# Price_per_sqft                                -0.014468
# ...                                                 ...
# Location_VIKAS NAGAR                          -0.000743
# Location_VISHAL NAGAR NIRMAN NAGAR            -0.000743
# Location_VIT CAMPUS                            1.000000
# Location_VIVEK VIHAR METRO STATION            -0.000743
# Location_VRDAWAN DHAM                         -0.000743
#
#                                     Location_VIVEK VIHAR METRO STATION  \
# Rent                                                         -0.003646
# BHK                                                          -0.009473
# Carpet Area                                                   0.009960
# Floor                                                        -0.002582
# Price_per_sqft                                               -0.012615
# ...                                                                ...
# Location_VIKAS NAGAR                                         -0.000743
# Location_VISHAL NAGAR NIRMAN NAGAR                           -0.000743
# Location_VIT CAMPUS                                          -0.000743
# Location_VIVEK VIHAR METRO STATION                            1.000000
# Location_VRDAWAN DHAM                                        -0.000743
#
#                                     Location_VRDAWAN DHAM
# Rent                                            -0.025400
# BHK                                             -0.040595
# Carpet Area                                     -0.003650
# Floor                                           -0.002582
# Price_per_sqft                                  -0.019223
# ...                                                   ...
# Location_VIKAS NAGAR                            -0.000743
# Location_VISHAL NAGAR NIRMAN NAGAR              -0.000743
# Location_VIT CAMPUS                             -0.000743
# Location_VIVEK VIHAR METRO STATION              -0.000743
# Location_VRDAWAN DHAM                            1.000000
#
# [341 rows x 341 columns]

# %% [markdown]
# > from the above corelation we can see that the Furnishing & Tenant feature do not have a good relation with rent so we have to drop them

# %% [markdown]
# ######

# %%
df.drop(columns=['Furnishing_Semi-Furnished',	'Furnishing_Unfurnished'], inplace=True)

# %%
df.drop(columns=['Tenant Preferred_Bachelors/Family','Tenant Preferred_Family'], inplace=True)
df.drop(columns=['Floor'], inplace=True)

# %%
df
# Out:
#          Rent  BHK  Carpet Area  Price_per_sqft  Location_1RK  \
# 0     26000.0  2.0     0.060325       21.138211         False
# 1     20000.0  2.0     0.053817       18.181818         False
# 2      7000.0  1.0     0.038798        8.750000         False
# 3     12000.0  2.0     0.064330        9.160305         False
# 4     32000.0  2.0     0.071740       21.947874         False
# ...       ...  ...          ...             ...           ...
# 1495  16000.0  2.0     0.045156       17.259978         False
# 1496  14000.0  2.0     0.058824       11.666667         False
# 1497  12500.0  2.0     0.041552       14.619883         False
# 1498  18500.0  2.0     0.046308       19.473684         False
# 1499  40000.0  4.0     0.088861       22.222222         False
#
#       Location_200 FEET BYPASS ROAD  Location_22 GODAM  \
# 0                             False              False
# 1                             False              False
# 2                             False              False
# 3                             False              False
# 4                             False              False
# ...                             ...                ...
# 1495                          False              False
# 1496                          False              False
# 1497                          False              False
# 1498                          False              False
# 1499                          False              False
#
#       Location_609, DEVI NAGAR NEW SANGANER ROAD SODALA  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 1495                                              False
# 1496                                              False
# 1497                                              False
# 1498                                              False
# 1499                                              False
#
#       Location_ACHARYA VOBA BHAVE NAGAR  Location_ADARSH NAGAR  ...  \
# 0                                 False                  False  ...
# 1                                 False                  False  ...
# 2                                 False                  False  ...
# 3                                 False                  False  ...
# 4                                 False                  False  ...
# ...                                 ...                    ...  ...
# 1495                              False                  False  ...
# 1496                              False                  False  ...
# 1497                              False                  False  ...
# 1498                              False                  False  ...
# 1499                              False                  False  ...
#
#       Location_VED VILLA COLONY  Location_VIDHADHAR NAGAR  \
# 0                         False                     False
# 1                         False                     False
# 2                         False                     False
# 3                         False                     False
# 4                         False                     False
# ...                         ...                       ...
# 1495                      False                     False
# 1496                      False                     False
# 1497                      False                     False
# 1498                      False                     False
# 1499                      False                     False
#
#       Location_VIDHYADHAR NAGAR  Location_VIDYADHAR NAGAR  \
# 0                         False                     False
# 1                         False                     False
# 2                         False                     False
# 3                         False                     False
# 4                         False                     False
# ...                         ...                       ...
# 1495                      False                     False
# 1496                      False                     False
# 1497                      False                     False
# 1498                      False                     False
# 1499                      False                     False
#
#       Location_VIDYUT NAGAR  Location_VIKAS NAGAR  \
# 0                     False                 False
# 1                     False                 False
# 2                     False                 False
# 3                     False                 False
# 4                     False                 False
# ...                     ...                   ...
# 1495                  False                 False
# 1496                  False                 False
# 1497                  False                 False
# 1498                  False                 False
# 1499                  False                 False
#
#       Location_VISHAL NAGAR NIRMAN NAGAR  Location_VIT CAMPUS  \
# 0                                  False                False
# 1                                  False                False
# 2                                  False                False
# 3                                  False                False
# 4                                  False                False
# ...                                  ...                  ...
# 1495                               False                False
# 1496                               False                False
# 1497                               False                False
# 1498                               False                False
# 1499                               False                False
#
#       Location_VIVEK VIHAR METRO STATION  Location_VRDAWAN DHAM
# 0                                  False                  False
# 1                                  False                  False
# 2                                  False                  False
# 3                                  False                  False
# 4                                  False                  False
# ...                                  ...                    ...
# 1495                               False                  False
# 1496                               False                  False
# 1497                               False                  False
# 1498                               False                  False
# 1499                               False                  False
#
# [1347 rows x 336 columns]

# %% [markdown]
# ####

# %% [markdown]
# ### Making .pkl files

# %%
import pickle

# %% [markdown]
# #### 1. Save the MinMaxScaler

# %%
with open("scaler.pkl", "wb") as f:
    pickle.dump(ms, f)

# %% [markdown]
# #### 2. Save the list of all locations (or other categories, if needed)

# %%
locations = df.columns[df.columns.str.startswith("Location_")].str.replace("Location_", "").tolist()
with open("location.pkl", "wb") as f:
    pickle.dump(locations, f)

# %% [markdown]
# #### 3. Save the final feature column names

# %%
feature_columns = df.drop(columns=["Rent"]).columns.tolist()
with open("feature_columns.pkl", "wb") as f:
    pickle.dump(feature_columns, f)

# %% [markdown]
# #

# %% [markdown]
# ## 5. Data Splitting

# %% [markdown]
# #### Splitting data into X & y

# %%
X = df.drop(columns=["Rent"])
y = df["Rent"]

# %% [markdown]
# #### Train test splitting

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2, random_state=121)

# %% [markdown]
# #

# %% [markdown]
# ## 6. Model Building & Evaluation

# %% [markdown]
# ######

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import SGDRegressor
from xgboost import XGBRegressor

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# #### Finding best model

# %%
models = [
    ('SGD', SGDRegressor(max_iter=5000, eta0=0.01, n_iter_no_change=100)),
    ('Random Forest', RandomForestRegressor()),
    ('KNN', KNeighborsRegressor()),
    ('XGB', XGBRegressor(n_estimators=500, learning_rate=0.05, random_state=2, max_depth= 2))
]


for name, model in models:
    print(f"{name}:-")

    model.fit(X_train, y_train)

    y_train_hat = model.predict(X_train)
    print(" Training:")
    print(f"   Acc: {r2_score(y_train, y_train_hat)*100:.2f}")
    print(f"   RMSE: {np.sqrt(mean_squared_error(y_train, y_train_hat)):.2f}\n")
    print('------------------')

    y_test_hat = model.predict(X_test)
    print(" Testing:")
    print(f"   Acc: {r2_score(y_test, y_test_hat)*100:.2f}")
    print(f"   RMSE: {np.sqrt(mean_squared_error(y_test, y_test_hat)):.2f}")
    print()
    print('============================================')
# Out:
# SGD:-
#  Training:
#    Acc: -331.42
#    RMSE: 25309.74
#
# ------------------
#  Testing:
#    Acc: 4.00
#    RMSE: 13493.57
#
# ============================================
# Random Forest:-
#  Training:
#    Acc: 99.56
#    RMSE: 807.14
#
# ------------------
#  Testing:
#    Acc: 94.26
#    RMSE: 3298.52
#
# ============================================
# KNN:-
#  Training:
#    Acc: 75.88
#    RMSE: 5984.22
#
# ------------------
#  Testing:
#    Acc: 67.85
#    RMSE: 7809.10
#
# ============================================
# XGB:-
#  Training:
#    Acc: 99.17
#    RMSE: 1110.89
#
# ------------------
#  Testing:
#    Acc: 96.36
#    RMSE: 2627.84
#
# ============================================

# %% [markdown]
# > XGB Regressor has least overfitting as compare to random forest and all other model has less accuracy then these 2 models

# %% [markdown]
# #####

# %% [markdown]
# #### Hyper-Parameters tunning

# %%
param = {
    'n_estimators': [100, 200, 300, 400, 500],
    'max_depth': [3, 4, 5, 6, 7],
    'learning_rate': [0.001, 0.01, 0.1, 0.2, 0.3]
}

# %% [markdown]
# ##### Randomized Search

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
xgb_regressor = XGBRegressor()
random_search = RandomizedSearchCV(xgb_regressor, param, n_iter=10, cv=5)
random_search.fit(X_train, y_train)
best_xgbr= random_search.best_estimator_
print("Best Parameters:", random_search.best_params_)
# Out:
# Best Parameters: {'n_estimators': 400, 'max_depth': 4, 'learning_rate': 0.1}

# %% [markdown]
# ######

# %%
y_test_pred= best_xgbr.predict(X_test)
y_train_pred= best_xgbr.predict(X_train)

# %%
print('Training: ', r2_score(y_train, y_train_pred)*100,'\n')
print('Testing: ', r2_score(y_test, y_test_pred)*100)
# Out:
# Training:  99.84885421931541
#
# Testing:  95.86570742516864

# %% [markdown]
# ######

# %% [markdown]
# #### Cross-Validation (CV)

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_scores = cross_val_score(xgb_regressor, X_train, y_train, cv=5, scoring='r2')
print("Cross-Validation Scores:", cv_scores)
print("Mean CV Score:", cv_scores.mean()*100)
# Out:
# Cross-Validation Scores: [0.96036459 0.94394123 0.98110254 0.98405186 0.95579906]
# Mean CV Score: 96.50518558225377

# %% [markdown]
# #####

# %% [markdown]
# #### Regression Plot

# %%
plt.scatter(y_test, y_test_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %%
sns.regplot(x=y_test,y=y_test_pred,ci=None,color ='red')
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %% [markdown]
# #

# %% [markdown]
# ## 7. Conclusion & Insights

# %% [markdown]
# **Project Summary**:
# > - Successfully built a machine learning model to predict rental prices using features like location, area, number of BHKs, furnishing status, and floor.
# > - Conducted thorough data preprocessing, feature engineering, and model evaluation to ensure reliable performance.
#
# **Key Insights**:
# > - Location and area have the strongest influence on rent prices.
# > - Outlier handling and feature scaling significantly improved model accuracy.
# > - Models like Random Forest and XGBoost provided higher R² scores compared to Linear Regression.
#
# **Model Performance**:
# > - The final model achieved an R² score of approximately **98%**.
# > - Cross-validation confirmed the model's consistency across different data splits.
#
# **Future Improvements**:
# > - Include more detailed location data (e.g., pin code, proximity to public transport).
# > - Add features like amenities, property age, and nearby landmarks.
# > - Integrate real-time data sources or APIs for dynamic rent prediction.
#
# **Real-World Applications**:
# > - This system can assist tenants in negotiating fair rent.
# > - Property owners can set competitive prices to maximize occupancy.
# > - Real estate platforms can integrate it for smarter listings.

# %% [markdown]
# ### Saving the model in model.pkl file

# %%
with open("model.pkl", "wb") as f:
    pickle.dump(best_xgbr, f)
